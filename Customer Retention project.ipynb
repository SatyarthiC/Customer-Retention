# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/CHITRAK/Desktop/GitHub/Customer retention dataset/CRD.csv", encoding = 'unicode_escape')
print(df)
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    int64
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (139, 71)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 242
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           139 non-null    int64
# ...

# %%
df.hist(bins=50,figsize=(25,20))
# Out:
# array([[<AxesSubplot:title={'center':'1Gender of respondent'}>,
#         <AxesSubplot:title={'center':'2 How old are you? '}>,
#         <AxesSubplot:title={'center':'4 What is the Pin Code of where you shop online from?'}>,
#         <AxesSubplot:title={'center':'5 Since How Long You are Shopping Online ?'}>,
#         <AxesSubplot:title={'center':'6 How many times you have made an online purchase in the past 1 year?'}>,
#         <AxesSubplot:title={'center':'7 How do you access the internet while shopping on-line?'}>,
#         <AxesSubplot:title={'center':'8 Which device do you use to access the online shopping?'}>],
#        [<AxesSubplot:title={'center':'9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '}>,
#         <AxesSubplot:title={'center':'10 What is the operating system (OS) of your device?\t\t\t\t                                          '}>,
# ...

# %%
df.hist('1Gender of respondent')
# Out:
# array([[<AxesSubplot:title={'center':'1Gender of respondent'}>]],
#       dtype=object)

# %%
df.hist('5 Since How Long You are Shopping Online ?')
# Out:
# array([[<AxesSubplot:title={'center':'5 Since How Long You are Shopping Online ?'}>]],
#       dtype=object)

# %%
df.hist('6 How many times you have made an online purchase in the past 1 year?')
# Out:
# array([[<AxesSubplot:title={'center':'6 How many times you have made an online purchase in the past 1 year?'}>]],
#       dtype=object)

# %%
df.hist('7 How do you access the internet while shopping on-line?')
# Out:
# array([[<AxesSubplot:title={'center':'7 How do you access the internet while shopping on-line?'}>]],
#       dtype=object)

# %%
df.hist('10 What is the operating system (OS) of your device?\t\t\t\t                                          ')
# Out:
# array([[<AxesSubplot:title={'center':'10 What is the operating system (OS) of your device?\t\t\t\t                                          '}>]],
#       dtype=object)

# %%
df.hist('13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ')
# Out:
# array([[<AxesSubplot:title={'center':'13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '}>]],
#       dtype=object)

# %%
df.hist('14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ')
# Out:
# array([[<AxesSubplot:title={'center':'14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '}>]],
#       dtype=object)

# %%
df.hist('15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ')
# Out:
# array([[<AxesSubplot:title={'center':'15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '}>]],
#       dtype=object)

# %%
df.hist('19 Information on similar product to the one highlighted  is important for product comparison')
# Out:
# array([[<AxesSubplot:title={'center':'19 Information on similar product to the one highlighted  is important for product comparison'}>]],
#       dtype=object)

# %%
df.hist('24 User friendly Interface of the website')
# Out:
# array([[<AxesSubplot:title={'center':'24 User friendly Interface of the website'}>]],
#       dtype=object)

# %%
df.hist('25 Convenient Payment methods')
# Out:
# array([[<AxesSubplot:title={'center':'25 Convenient Payment methods'}>]],
#       dtype=object)

# %%
df.hist('26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time')
# Out:
# array([[<AxesSubplot:title={'center':'26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'}>]],
#       dtype=object)

# %%
df.hist('28 Being able to guarantee the privacy of the customer')
# Out:
# array([[<AxesSubplot:title={'center':'28 Being able to guarantee the privacy of the customer'}>]],
#       dtype=object)

# %%
df.hist('29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)')
# Out:
# array([[<AxesSubplot:title={'center':'29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'}>]],
#       dtype=object)

# %%
df.hist('30 Online shopping gives monetary benefit and discounts')
# Out:
# array([[<AxesSubplot:title={'center':'30 Online shopping gives monetary benefit and discounts'}>]],
#       dtype=object)

# %%
df.hist('31 Enjoyment is derived from shopping online')
# Out:
# array([[<AxesSubplot:title={'center':'31 Enjoyment is derived from shopping online'}>]],
#       dtype=object)

# %%
df.hist('33 Return and replacement policy of the e-tailer is important for purchase decision')
# Out:
# array([[<AxesSubplot:title={'center':'33 Return and replacement policy of the e-tailer is important for purchase decision'}>]],
#       dtype=object)

# %%
df.hist('38 User satisfaction cannot exist without trust')
# Out:
# array([[<AxesSubplot:title={'center':'38 User satisfaction cannot exist without trust'}>]],
#       dtype=object)

# %%
df.hist('39 Offering a wide variety of listed product in several category')
# Out:
# array([[<AxesSubplot:title={'center':'39 Offering a wide variety of listed product in several category'}>]],
#       dtype=object)

# %%
df.hist('46 Shopping on the website helps you fulfill certain roles')
# Out:
# array([[<AxesSubplot:title={'center':'46 Shopping on the website helps you fulfill certain roles'}>]],
#       dtype=object)

# %%
df.hist('47 Getting value for money spent')
# Out:
# array([[<AxesSubplot:title={'center':'47 Getting value for money spent'}>]],
#       dtype=object)
